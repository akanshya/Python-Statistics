# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy.stats as s

# %%
dataset=pd.read_csv("D:\Data Science\sales_data.csv")

# %%
dataset
# Out:
#         User_ID Product_ID Gender    Age  Occupation       City  \
# 0       1000001  P00069042      F   0-17          10  Hyderabad
# 1       1000001  P00248942      F   0-17          10  Hyderabad
# 2       1000001  P00087842      F   0-17          10  Hyderabad
# 3       1000001  P00085442      F   0-17          10  Hyderabad
# 4       1000002  P00285442      M    55+          16    Chennai
# ...         ...        ...    ...    ...         ...        ...
# 550063  1006033  P00372445      M  51-55          13  Bangalore
# 550064  1006035  P00375436      F  26-35           1    Chennai
# 550065  1006036  P00375436      F  26-35          15  Bangalore
# 550066  1006038  P00375436      F    55+           1    Chennai
# 550067  1006039  P00371644      F  46-50           0  Bangalore
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
dataset["Purchase"]
# Out:
# 0          8370
# 1         15200
# 2          1422
# 3          1057
# 4          7969
#           ...
# 550063      368
# 550064      371
# 550065      137
# 550066      365
# 550067      490
# Name: Purchase, Length: 550068, dtype: int64

# %%
sns.distplot(dataset["Purchase"])

# %% [markdown]
# # Step -1 Sampling / Randomly pick samples from the data

# %%
import random

# %%
np.mean(random.choices(dataset["Purchase"],k=20))#dataset,k- no of observations
# Out:
# 8250.9

# %%
n=100 #total no of samples
k1=100 #total no of observation

# %%
sample_data=[]

# %%
for i in range(0,n):
    sample_data.append(random.choices(dataset["Purchase"],k=k1))

# %%
sample_data
# Out:
# [[12019,
#   7415,
#   8621,
#   15835,
#   19243,
#   3858,
#   6952,
#   8753,
#   6077,
#   8652,
#   10634,
#   8321,
#   15878,
#   7040,
#   6044,
#   8001,
#   1435,
#   11819,
#   11490,
#   10152,
#   8844,
#   10080,
#   16493,
#   6870,
#   20236,
#   19160,
#   7680,
#   5281,
#   6884,
#   2108,
#   4642,
#   8657,
#   15794,
#   3594,
#   15844,
#   6040,
#   4500,
#   23344,
#   15193,
#   19021,
#   8711,
#   15670,
#   6890,
#   6994,
#   9773,
#   13548,
#   12090,
#   7929,
#   15266,
#   15796,
#   11498,
#   15713,
#   15816,
#   8036,
#   6002,
#   15659,
#   19186,
#   8058,
#   7763,
#   13658,
#   5422,
#   11988,
#   16392,
#   11766,
#   6153,
#   11463,
#   8870,
#   5214,
#   8049,
#   19525,
#   18987,
#   800,
#   3439,
#   19267,
#   3738,
#   5430,
#   4607,
#   16231,
#   13678,
#   15784,
#   1065,
#   1517,
#   20287,
#   15669,
#   6938,
#   2394,
#   23510,
#   6961,
#   9755,
#   6156,
#   19182,
#   8486,
#   12105,
#   20740,
#   12918,
# ...

# %%
sample_means=[]

# %%
for i in sample_data:
    sample_means.append(np.mean(i))

# %%
sample_means
# Out:
# [10591.65,
#  10334.29,
#  9703.28,
#  9486.37,
#  8694.92,
#  9320.03,
#  9405.72,
#  8855.41,
#  9742.06,
#  10439.5,
#  9085.05,
#  9508.88,
#  9086.85,
#  9021.12,
#  10148.25,
#  9690.74,
#  9011.22,
#  9109.44,
#  8920.69,
#  9720.62,
#  9320.23,
#  10589.94,
#  9220.07,
#  9946.75,
#  9658.82,
#  9708.58,
#  8416.26,
#  9353.76,
#  9162.8,
#  9320.14,
#  9884.36,
#  9224.2,
#  8405.07,
#  9525.26,
#  9407.7,
#  8879.55,
#  9507.05,
#  8993.78,
#  9502.67,
#  8890.35,
#  8658.32,
#  9443.66,
#  8941.91,
#  9916.28,
#  9157.97,
#  9015.86,
#  9252.08,
#  8721.95,
#  9790.16,
#  9774.34,
#  9091.94,
#  9112.41,
#  8538.5,
#  8640.9,
#  9799.63,
#  9496.94,
#  8446.87,
#  9565.25,
#  9244.16,
#  8787.28,
#  9765.66,
#  8780.58,
#  9074.29,
#  9121.64,
#  8591.38,
#  8075.71,
#  9608.76,
#  9541.68,
#  9116.43,
#  9648.23,
#  9487.18,
#  8689.42,
#  10272.93,
#  9456.28,
#  9179.77,
#  9239.02,
#  9172.79,
#  9618.54,
#  9451.56,
#  9374.16,
#  9078.91,
#  9426.46,
#  10235.81,
# ...

# %%
sns.distplot(sample_means)

# %% [markdown]
# # Mean of sample means

# %%
smean=np.mean(sample_means)

# %%
#Sample Mean
smean #k=30
# Out:
# 9335.6927

# %%
#Population mean
dataset["Purchase"].mean()
# Out:
# 9263.968712959126

# %% [markdown]
# # Variance

# %%
svar=np.var(sample_means)

# %%
svar
# Out:
# 233998.33460770998

# %%
#Population variance
dataset["Purchase"].var()/100
# Out:
# 252311.85950598365

# %% [markdown]
# # Standard Deviation

# %%
sstd=np.std(sample_means)

# %%
sstd
# Out:
# 483.73374350742785

# %%
#Population std
dataset["Purchase"].std()/np.sqrt(100)
# Out:
# 502.3065393820627

# %% [markdown]
# # Hence Proved
# 1. Sample Statistic will approximate population statistic when sample size high and randomly picked

# %% [markdown]
# # Confidence Interval

# %% [markdown]
# # 95% Confidence

# %%
smean
# Out:
# 9335.6927

# %%
z=1.960

# %%
sstd=dataset["Purchase"].std()/np.sqrt(100)

# %%
lower_limit=smean-((z)*sstd)

# %%
lower_limit
# Out:
# 8351.171882811157

# %%
upper_limit=smean+((z)*sstd)

# %%
upper_limit
# Out:
# 10320.213517188842

# %% [markdown]
# # 90% Confidence

# %%
z=1.64

# %%
lower_limit=smean-((z)*sstd)

# %%
upper_limit=smean+((z)*sstd)

# %%
lower_limit
# Out:
# 8511.909975413417

# %%
upper_limit
# Out:
# 10159.475424586582

# %% [markdown]
# # 99% Confidence

# %%
z=2.576

# %%
lower_limit=smean-((z)*sstd)

# %%
upper_limit=smean+((z)*sstd)

# %%
lower_limit
# Out:
# 8041.751054551806

# %%
upper_limit
# Out:
# 10629.634345448194

# %% [markdown]
# # Observation
# 1. We are 90% confident that the true mean lies between 8511 to 10159 --Narrow
# 2. We are 95% confident that the true mean lies between 8351 to 10320 --Wide
# 3. We are 99% confident that the true mean lies between 8041 to 10629 --Wider
